# %%
from os import listdir
from PIL import Image as PImage
#from matplotlib.pyplot import imshow
#import numpy as np
from IPython.display import display
from skfuzzy import filters as fuzzyF

def loadImages(path):
    # return array of images

    imagesList = listdir(path)
    loadedImages = []
    for image in imagesList:
        img = PImage.open(path + image)
        loadedImages.append(img)

    return loadedImages

path = "./lymp/"

# your images in an array
imgs = loadImages(path)

counter=0
for img in imgs:
    # you can show every image
    counter=counter+1
    #imshow(np.asarray(img))
    #imshow(img)
    display(img)
    fuzzyF.fire2d(img, l1=0, l2=255, fuzzyresolution=1)
    
print(counter)
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=720x576 at 0x7FF2F81D7A58>
# AttributeErrorTraceback (most recent call last)
# <ipython-input-22-50eb92be483f> in <module>
#      29     #imshow(img)
#      30     display(img)
# ---> 31     fuzzyF.fire2d(img, l1=0, l2=255, fuzzyresolution=1)
#      32
#      33 print(counter)
#
# /opt/conda/lib/python3.7/site-packages/skfuzzy/filters/fire.py in fire2d(im, l1, l2, fuzzyresolution)
#     129     from ..image import pad as padimg
#     130
# --> 131     im = padimg(im.astype(float), 1, mode='reflect')
#     132
#     133     # Fuzzy input sequence
#
# AttributeError: 'BmpImageFile' object has no attribute 'astype'
